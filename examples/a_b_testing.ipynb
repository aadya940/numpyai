# %%
import numpyai as npi
import numpy as np
# Out:
# Ensure your API KEY is set for your LLM as an environment variable.
# Ensure your API KEY is set for your LLM as an environment variable.

# %%
np.random.seed(42)  # For consistent results

# %%
# Simulate conversions for group A (10% conversion rate)
a_data = np.random.binomial(n=1, p=0.10, size=1000)

# Simulate conversions for group B (12% conversion rate)
b_data = np.random.binomial(n=1, p=0.12, size=1000)

# %%
# Start a NumPyAI session with both arrays
sess = npi.NumpyAISession([a_data, b_data], verbose=True, model_name="gemini-2.5-pro-preview-03-25")

# %%
print(sess.chat("What is the conversion rate of each group?"))  # → Should return two means
# Out:
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Query: What is the conversion rate of each group?                                                               │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Attempt 1/3...                                                                                                  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────────────────────── Generated Code ─────────────────────────────────────────────────╮
# │    1 # Calculate the conversion rate for each group.                                                            │
# │    2 # Assuming arr1 represents the number of conversions for group 1 and arr2 represents the number of convers │
# │    3 # Further assuming that the total number of users in each group is 1000 (based on the array shape).        │
# │    4 # Conversion rate is calculated as (number of conversions / total number of users) * 100                   │
# │    5                                                                                                            │
# │    6 total_users = arr1.shape[0] # Total number of users, based on array shape                                  │
# │    7                                                                                                            │
# │    8 conversion_rate_arr1 = (np.sum(arr1) / total_users) * 100                                                  │
# │    9 conversion_rate_arr2 = (np.sum(arr2) / total_users) * 100                                                  │
# │   10                                                                                                            │
# │   11 output = np.array([conversion_rate_arr1, conversion_rate_arr2])                                            │
# │   12                                                                                                            │
# │   13 print("Conversion Rate of Group 1:", conversion_rate_arr1)                                                 │
# │   14 print("Conversion Rate of Group 2:", conversion_rate_arr2)                                                 │
# │   15                                                                                                            │
# │   16 metadata = "The variable output is a numpy array containing the conversion rates of group 1 and group 2, r │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Conversion Rate of Group 1: 10.0
# Conversion Rate of Group 2: 11.200000000000001
# [10.  11.2]
# The variable output is a numpy array containing the conversion rates of group 1 and group 2, respectively. The
# conversion rate is calculated as the number of conversions divided by the total number of users (1000) and
# multiplied by 100.  The first element corresponds to group 1, and the second element corresponds to group 2.
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ ✗ Attempt 1 failed: list index out of range                                                                     │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Attempt 2/3...                                                                                                  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────────────────────── Generated Code ─────────────────────────────────────────────────╮
# │   1 conversion_rate_arr1 = np.mean(arr1)                                                                        │
# │   2 conversion_rate_arr2 = np.mean(arr2)                                                                        │
# │   3                                                                                                             │
# │   4 output = np.array([conversion_rate_arr1, conversion_rate_arr2])                                             │
# │   5                                                                                                             │
# │   6 print(f"Conversion rate of arr1: {conversion_rate_arr1}")                                                   │
# │   7 print(f"Conversion rate of arr2: {conversion_rate_arr2}")                                                   │
# │   8                                                                                                             │
# │   9 metadata = "The variable output is a numpy array of shape (2,) containing the conversion rates of arr1 and  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Conversion rate of arr1: 0.1
# Conversion rate of arr2: 0.112
# [0.1   0.112]
# The variable output is a numpy array of shape (2,) containing the conversion rates of arr1 and arr2, respectively.
# The conversion rate is calculated as the mean of each array, representing the proportion of non-zero elements.
# ╭──────────────────────────────────────────────── Validation Code ────────────────────────────────────────────────╮
# │    1 output = None                                                                                              │
# │    2 if type(code_out) != type(None):                                                                           │
# │    3     # Check if the output is a numpy array.                                                                │
# │    4     if isinstance(code_out, np.ndarray):                                                                   │
# │    5         # Check the shape of the output array.                                                             │
# │    6         if code_out.shape == (2,):                                                                         │
# │    7             # Check the data type of the output array.                                                     │
# │    8             if code_out.dtype == np.float64:                                                               │
# │    9                 # Calculate the expected conversion rates.                                                 │
# │   10                 expected_cr1 = np.mean(arr1)                                                               │
# │   11                 expected_cr2 = np.mean(arr2)                                                               │
# │   12                 expected_output = np.array([expected_cr1, expected_cr2])                                   │
# │   13                                                                                                            │
# │   14                 # Compare the output with the expected output, allowing for numerical tolerance.           │
# │   15                 if np.allclose(code_out, expected_output, rtol=1e-05):                                     │
# │   16                     output = True                                                                          │
# │   17                 else:                                                                                      │
# │   18                     output = False                                                                         │
# │   19             else:                                                                                          │
# │   20                 output = False                                                                             │
# │   21         else:                                                                                              │
# │   22             output = False                                                                                 │
# │   23     else:                                                                                                  │
# │   24         output = False                                                                                     │
# │   25 else:                                                                                                      │
# │   26     output = False                                                                                         │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# True
# None
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Validation Successful.                                                                                          │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Output                                                                                                          │
# │  <class 'numpy.ndarray'>                                                                                        │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# [0.1   0.112]

# %%
# Chat: Perform a z-test to compare the conversion rates
print(sess.chat("Perform a z-test to determine if the difference is statistically significant."))
# Out:
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Query: Perform a z-test to determine if the difference is statistically significant.                            │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Attempt 1/3...                                                                                                  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────────────────────── Generated Code ─────────────────────────────────────────────────╮
# │   1 n1 = arr1.size                                                                                              │
# │   2 n2 = arr2.size                                                                                              │
# │   3 p1 = np.mean(arr1)                                                                                          │
# │   4 p2 = np.mean(arr2)                                                                                          │
# │   5 pooled_variance = (p1 * (1 - p1) / n1) + (p2 * (1 - p2) / n2)                                               │
# │   6 z = (p1 - p2) / np.sqrt(pooled_variance)                                                                    │
# │   7 output = z                                                                                                  │
# │   8 metadata = "The variable output is a numpy scalar representing the z-statistic calculated from arr1 and arr │
# │   9 print(f"Z-statistic: {output}")                                                                             │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Z-statistic: -0.8718204746129764
# -0.8718204746129764
# The variable output is a numpy scalar representing the z-statistic calculated from arr1 and arr2.
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ ✗ Attempt 1 failed: list index out of range                                                                     │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Attempt 2/3...                                                                                                  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────────────────────── Generated Code ─────────────────────────────────────────────────╮
# │   1 n1 = arr1.size                                                                                              │
# │   2 n2 = arr2.size                                                                                              │
# │   3 p1 = np.mean(arr1)                                                                                          │
# │   4 p2 = np.mean(arr2)                                                                                          │
# │   5 pooled_variance = (p1 * (1 - p1) / n1) + (p2 * (1 - p2) / n2)                                               │
# │   6 z = (p1 - p2) / np.sqrt(pooled_variance)                                                                    │
# │   7 output = z                                                                                                  │
# │   8 metadata = "The variable output is a numpy scalar representing the Z-statistic from a Z-test comparing the  │
# │   9 print(f"Z-statistic: {output}")                                                                             │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Z-statistic: -0.8718204746129764
# -0.8718204746129764
# The variable output is a numpy scalar representing the Z-statistic from a Z-test comparing the means of arr1 and
# arr2.
# ╭──────────────────────────────────────────────── Validation Code ────────────────────────────────────────────────╮
# │    1 n1 = arr1.size                                                                                             │
# │    2 n2 = arr2.size                                                                                             │
# │    3 mean1 = np.mean(arr1)                                                                                      │
# │    4 mean2 = np.mean(arr2)                                                                                      │
# │    5 std1 = np.std(arr1)                                                                                        │
# │    6 std2 = np.std(arr2)                                                                                        │
# │    7                                                                                                            │
# │    8 if std1 == 0 and std2 == 0:                                                                                │
# │    9     if mean1 == mean2:                                                                                     │
# │   10         z = 0.0                                                                                            │
# │   11     else:                                                                                                  │
# │   12         z = np.inf if mean1 > mean2 else -np.inf                                                           │
# │   13 elif std1 == 0:                                                                                            │
# │   14     z = (mean1 - mean2) / (std2 / np.sqrt(n2))                                                             │
# │   15 elif std2 == 0:                                                                                            │
# │   16     z = (mean1 - mean2) / (std1 / np.sqrt(n1))                                                             │
# │   17 else:                                                                                                      │
# │   18     z = (mean1 - mean2) / np.sqrt((std1**2 / n1) + (std2**2 / n2))                                         │
# │   19                                                                                                            │
# │   20 output = np.isclose(code_out, z, rtol=1e-05)                                                               │
# │   21                                                                                                            │
# │   22 metadata = "The variable output is a boolean. It's True if the z-statistic is validated; otherwise, it is  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# True
# The variable output is a boolean. It's True if the z-statistic is validated; otherwise, it is False. The
# z-statistic is calculated independently using numpy and compared with the original z-statistic.
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Validation Successful.                                                                                          │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Output                                                                                                          │
# │  -0.8718204746129764                                                                                            │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# -0.8718204746129764

# %%
print(sess.chat("Which group performed better, and is the difference significant?"))
# Out:
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Query: Which group performed better, and is the difference significant?                                         │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Attempt 1/3...                                                                                                  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────────────────────── Generated Code ─────────────────────────────────────────────────╮
# │    1 mean1 = np.mean(arr1)                                                                                      │
# │    2 mean2 = np.mean(arr2)                                                                                      │
# │    3                                                                                                            │
# │    4 if mean1 > mean2:                                                                                          │
# │    5     better_group = "Group 1"                                                                               │
# │    6 elif mean2 > mean1:                                                                                        │
# │    7     better_group = "Group 2"                                                                               │
# │    8 else:                                                                                                      │
# │    9     better_group = "Both groups performed equally"                                                         │
# │   10                                                                                                            │
# │   11 # Calculate the pooled standard deviation                                                                  │
# │   12 pooled_sd = np.sqrt((np.std(arr1)**2 + np.std(arr2)**2) / 2)                                               │
# │   13                                                                                                            │
# │   14 # Calculate the Z-statistic                                                                                │
# │   15 z_statistic = (mean1 - mean2) / (pooled_sd * np.sqrt(2/len(arr1)))                                         │
# │   16                                                                                                            │
# │   17 # Define a significance level (alpha)                                                                      │
# │   18 alpha = 0.05                                                                                               │
# │   19                                                                                                            │
# │   20 # Calculate the p-value for a two-tailed test                                                              │
# │   21 p_value = 2 * (1 - np.abs(0.5 * (1 + np.real(np.sqrt(1) * np.imag(np.exp(-z_statistic * z_statistic / 2) / │
# │   22                                                                                                            │
# │   23 # Determine if the difference is statistically significant                                                 │
# │   24 if p_value < alpha:                                                                                        │
# │   25     significant = "significantly"                                                                          │
# │   26 else:                                                                                                      │
# │   27     significant = "not significantly"                                                                      │
# │   28                                                                                                            │
# │   29 output = f"{better_group} performed better, and the difference is {significant} significant."              │
# │   30                                                                                                            │
# │   31 print(f"Group 1 Conversion Rate: {mean1:.3f}")                                                             │
# │   32 print(f"Group 2 Conversion Rate: {mean2:.3f}")                                                             │
# │   33 print(f"Z-statistic: {z_statistic:.3f}")                                                                   │
# │   34 print(f"P-value: {p_value:.3f}")                                                                           │
# │   35 print(output)                                                                                              │
# │   36                                                                                                            │
# │   37 metadata = "The variable 'output' is a string indicating which group performed better (based on conversion │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Group 1 Conversion Rate: 0.100
# Group 2 Conversion Rate: 0.112
# Z-statistic: -0.872
# P-value: 1.000
# Group 2 performed better, and the difference is not significantly significant.
# Group 2 performed better, and the difference is not significantly significant.
# The variable 'output' is a string indicating which group performed better (based on conversion rate) and whether
# the difference between the groups is statistically significant (based on a Z-test with alpha=0.05).
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ ✗ Attempt 1 failed: list index out of range                                                                     │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Attempt 2/3...                                                                                                  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────────────────────── Generated Code ─────────────────────────────────────────────────╮
# │    1 mean1 = np.mean(arr1)                                                                                      │
# │    2 mean2 = np.mean(arr2)                                                                                      │
# │    3                                                                                                            │
# │    4 print(f"Mean of arr1: {mean1}")                                                                            │
# │    5 print(f"Mean of arr2: {mean2}")                                                                            │
# │    6                                                                                                            │
# │    7 if mean2 > mean1:                                                                                          │
# │    8     better_group = "arr2"                                                                                  │
# │    9 else:                                                                                                      │
# │   10     better_group = "arr1"                                                                                  │
# │   11                                                                                                            │
# │   12 print(f"Group {better_group} performed better based on the mean.")                                         │
# │   13                                                                                                            │
# │   14 # Perform Z-test (using a simplified approach since no other libraries are allowed)                        │
# │   15 n1 = arr1.size                                                                                             │
# │   16 n2 = arr2.size                                                                                             │
# │   17 pooled_std = np.sqrt((np.std(arr1)**2 / n1) + (np.std(arr2)**2 / n2))                                      │
# │   18                                                                                                            │
# │   19 if pooled_std == 0:                                                                                        │
# │   20     z_statistic = 0  # Avoid division by zero                                                              │
# │   21 else:                                                                                                      │
# │   22     z_statistic = (mean1 - mean2) / pooled_std                                                             │
# │   23                                                                                                            │
# │   24 print(f"Z-statistic: {z_statistic}")                                                                       │
# │   25                                                                                                            │
# │   26 # Define a significance level (alpha)                                                                      │
# │   27 alpha = 0.05                                                                                               │
# │   28                                                                                                            │
# │   29 # Calculate the critical value (two-tailed test) - Simplified approximation                                │
# │   30 critical_value = 1.96                                                                                      │
# │   31                                                                                                            │
# │   32 # Check for significance                                                                                   │
# │   33 if np.abs(z_statistic) > critical_value:                                                                   │
# │   34     significant = True                                                                                     │
# │   35     significance_message = "The difference is statistically significant."                                  │
# │   36 else:                                                                                                      │
# │   37     significant = False                                                                                    │
# │   38     significance_message = "The difference is not statistically significant."                              │
# │   39                                                                                                            │
# │   40 print(significance_message)                                                                                │
# │   41                                                                                                            │
# │   42 # Combine the results into a structured string.  Since we're restricted from using more complex data struc │
# │   43 output = f"Better group: {better_group}, Significant: {significant}, Z-statistic: {z_statistic}"           │
# │   44                                                                                                            │
# │   45 metadata = "The variable output is a string indicating which group (arr1 or arr2) performed better based o │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Mean of arr1: 0.1
# Mean of arr2: 0.112
# Group arr2 performed better based on the mean.
# Z-statistic: -0.8718204746129764
# The difference is not statistically significant.
# Better group: arr2, Significant: False, Z-statistic: -0.8718204746129764
# The variable output is a string indicating which group (arr1 or arr2) performed better based on their means,
# whether the difference is statistically significant based on a Z-test, and the Z-statistic.  A simplified Z-test
# was performed without external libraries, and significance was determined using a critical value of 1.96 for a
# two-tailed test at alpha=0.05.
# ╭──────────────────────────────────────────────── Validation Code ────────────────────────────────────────────────╮
# │    1 mean1 = np.mean(arr1)                                                                                      │
# │    2 mean2 = np.mean(arr2)                                                                                      │
# │    3 z_statistic = (mean1 - mean2) / np.sqrt((np.var(arr1) / arr1.size) + (np.var(arr2) / arr2.size))           │
# │    4                                                                                                            │
# │    5 significant = np.abs(z_statistic) > 1.96 # Simplified significance check                                   │
# │    6                                                                                                            │
# │    7 if mean1 > mean2:                                                                                          │
# │    8     better_group = "arr1"                                                                                  │
# │    9 elif mean2 > mean1:                                                                                        │
# │   10     better_group = "arr2"                                                                                  │
# │   11 else:                                                                                                      │
# │   12     better_group = "both"                                                                                  │
# │   13                                                                                                            │
# │   14 output = f"Better group: {better_group}, Significant: {significant}, Z-statistic: {z_statistic}"           │
# │   15 metadata = "A string indicating which group performed better, significance of the difference, and the z-st │
# │   16                                                                                                            │
# │   17 print(f"Group 1 Mean: {mean1}")                                                                            │
# │   18 print(f"Group 2 Mean: {mean2}")                                                                            │
# │   19 print(f"Z-statistic: {z_statistic}")                                                                       │
# │   20 print(f"Significance: {significant}")                                                                      │
# │   21 print(f"Better Group: {better_group}")                                                                     │
# │   22 print(f"Output: {output}")                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Group 1 Mean: 0.1
# Group 2 Mean: 0.112
# Z-statistic: -0.8718204746129764
# Significance: False
# Better Group: arr2
# Output: Better group: arr2, Significant: False, Z-statistic: -0.8718204746129764
# Better group: arr2, Significant: False, Z-statistic: -0.8718204746129764
# A string indicating which group performed better, significance of the difference, and the z-statistic.
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Validation Successful.                                                                                          │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Output                                                                                                          │
# │  Better group: arr2, Significant: False, Z-statistic: -0.8718204746129764                                       │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Better group: arr2, Significant: False, Z-statistic: -0.8718204746129764
