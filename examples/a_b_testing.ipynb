# %%
import numpyai as npi
import numpy as np
# Out:
# Ensure your API KEY is set for your LLM as an environment variable.
# Ensure your API KEY is set for your LLM as an environment variable.

# %%
np.random.seed(42)  # For consistent results

# %%
# Simulate conversions for group A (10% conversion rate)
a_data = np.random.binomial(n=1, p=0.10, size=1000)

# Simulate conversions for group B (12% conversion rate)
b_data = np.random.binomial(n=1, p=0.12, size=1000)

# %%
# Start a NumPyAI session with both arrays
sess = npi.NumpyAISession([a_data, b_data])

# %%
print(sess.chat("What is the conversion rate of each group?"))  # → Should return two means
# Out:
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Query: What is the conversion rate of each group?                                                               │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Attempt 1/3...                                                                                                  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────────────────────── Generated Code ─────────────────────────────────────────────────╮
# │    1 # Calculate the conversion rate for each group.                                                            │
# │    2 # Assuming arr1 and arr2 represent two groups, where 1 indicates a conversion and 0 indicates no conversio │
# │    3 # The conversion rate is the number of conversions divided by the total number of elements in the group.   │
# │    4                                                                                                            │
# │    5 # Calculate the number of conversions in arr1                                                              │
# │    6 conversions_arr1 = np.sum(arr1)                                                                            │
# │    7                                                                                                            │
# │    8 # Calculate the number of conversions in arr2                                                              │
# │    9 conversions_arr2 = np.sum(arr2)                                                                            │
# │   10                                                                                                            │
# │   11 # Calculate the total number of elements in arr1                                                           │
# │   12 total_arr1 = arr1.size                                                                                     │
# │   13                                                                                                            │
# │   14 # Calculate the total number of elements in arr2                                                           │
# │   15 total_arr2 = arr2.size                                                                                     │
# │   16                                                                                                            │
# │   17 # Calculate the conversion rate for arr1                                                                   │
# │   18 conversion_rate_arr1 = conversions_arr1 / total_arr1                                                       │
# │   19                                                                                                            │
# │   20 # Calculate the conversion rate for arr2                                                                   │
# │   21 conversion_rate_arr2 = conversions_arr2 / total_arr2                                                       │
# │   22                                                                                                            │
# │   23 # Store the conversion rates in a single array                                                             │
# │   24 output = np.array([conversion_rate_arr1, conversion_rate_arr2])                                            │
# │   25                                                                                                            │
# │   26 print("Conversion Rate Array 1:", conversion_rate_arr1)                                                    │
# │   27 print("Conversion Rate Array 2:", conversion_rate_arr2)                                                    │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Conversion Rate Array 1: 0.1
# Conversion Rate Array 2: 0.112
# [0.1   0.112]
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ ✗ Attempt 1 failed: list index out of range                                                                     │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Attempt 2/3...                                                                                                  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────────────────────── Generated Code ─────────────────────────────────────────────────╮
# │    1 # Calculate the conversion rate for each group.                                                            │
# │    2 conversion_rate_arr1 = np.mean(arr1)                                                                       │
# │    3 conversion_rate_arr2 = np.mean(arr2)                                                                       │
# │    4                                                                                                            │
# │    5 # Store the conversion rates in a single array.                                                            │
# │    6 output = np.array([conversion_rate_arr1, conversion_rate_arr2])                                            │
# │    7                                                                                                            │
# │    8 # Print the conversion rates for each group.                                                               │
# │    9 print("Conversion Rate for Group 1 (arr1):", conversion_rate_arr1)                                         │
# │   10 print("Conversion Rate for Group 2 (arr2):", conversion_rate_arr2)                                         │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Conversion Rate for Group 1 (arr1): 0.1
# Conversion Rate for Group 2 (arr2): 0.112
# [0.1   0.112]
# ╭──────────────────────────────────────────────── Validation Code ────────────────────────────────────────────────╮
# │   1 group1_conversion_rate = np.sum(arr1) / arr1.size                                                           │
# │   2 group2_conversion_rate = np.sum(arr2) / arr2.size                                                           │
# │   3 output = np.array([group1_conversion_rate, group2_conversion_rate])                                         │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# [0.1   0.112]
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ ✗ Attempt 2 failed: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all() │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Attempt 3/3...                                                                                                  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────────────────────── Generated Code ─────────────────────────────────────────────────╮
# │   1 conversion_rate_arr1 = np.mean(arr1)                                                                        │
# │   2 conversion_rate_arr2 = np.mean(arr2)                                                                        │
# │   3                                                                                                             │
# │   4 output = np.array([conversion_rate_arr1, conversion_rate_arr2])                                             │
# │   5                                                                                                             │
# │   6 print("Conversion Rate for arr1:", conversion_rate_arr1)                                                    │
# │   7 print("Conversion Rate for arr2:", conversion_rate_arr2)                                                    │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Conversion Rate for arr1: 0.1
# Conversion Rate for arr2: 0.112
# [0.1   0.112]
# ╭──────────────────────────────────────────────── Validation Code ────────────────────────────────────────────────╮
# │    1 group1_conversion_rate = np.sum(arr1) / arr1.size                                                          │
# │    2 group2_conversion_rate = np.sum(arr2) / arr2.size                                                          │
# │    3 output = np.array([group1_conversion_rate, group2_conversion_rate])                                        │
# │    4 print("Conversion Rate for Group 1:", group1_conversion_rate)                                              │
# │    5 print("Conversion Rate for Group 2:", group2_conversion_rate)                                              │
# │    6                                                                                                            │
# │    7                                                                                                            │
# │    8                                                                                                            │
# │    9 # Independent validation of the conversion rates                                                           │
# │   10 expected_shape = (2,)                                                                                      │
# │   11 expected_dtype = np.float64                                                                                │
# │   12                                                                                                            │
# │   13 # Check shape                                                                                              │
# │   14 shape_check = code_out.shape == expected_shape                                                             │
# │   15                                                                                                            │
# │   16 # Check dtype                                                                                              │
# │   17 dtype_check = code_out.dtype == expected_dtype                                                             │
# │   18                                                                                                            │
# │   19 # Calculate conversion rates directly from array properties                                                │
# │   20 group1_expected = arr1.sum() / arr1.size                                                                   │
# │   21 group2_expected = arr2.sum() / arr2.size                                                                   │
# │   22 expected_output = np.array([group1_expected, group2_expected])                                             │
# │   23                                                                                                            │
# │   24 # Check values using np.allclose with tolerance                                                            │
# │   25 value_check = np.allclose(code_out, expected_output, rtol=1e-5)                                            │
# │   26                                                                                                            │
# │   27 # Combine checks                                                                                           │
# │   28 output = shape_check and dtype_check and value_check                                                       │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Conversion Rate for Group 1: 0.1
# Conversion Rate for Group 2: 0.112
# True
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Validation Successful.                                                                                          │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Output                                                                                                          │
# │  <class 'numpy.ndarray'>                                                                                        │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# [0.1   0.112]

# %%
# Chat: Perform a z-test to compare the conversion rates
print(sess.chat("Perform a z-test to determine if the difference is statistically significant."))
# Out:
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Query: Perform a z-test to determine if the difference is statistically significant.                            │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Attempt 1/3...                                                                                                  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────────────────────── Generated Code ─────────────────────────────────────────────────╮
# │   1 n1 = arr1.size                                                                                              │
# │   2 n2 = arr2.size                                                                                              │
# │   3 p1 = np.mean(arr1)                                                                                          │
# │   4 p2 = np.mean(arr2)                                                                                          │
# │   5                                                                                                             │
# │   6 print(f"Conversion rate of group 1: {p1}")                                                                  │
# │   7 print(f"Conversion rate of group 2: {p2}")                                                                  │
# │   8                                                                                                             │
# │   9 output = np.array([p1, p2])                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Conversion rate of group 1: 0.1
# Conversion rate of group 2: 0.112
# [0.1   0.112]
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ ✗ Attempt 1 failed: list index out of range                                                                     │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Attempt 2/3...                                                                                                  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────────────────────── Generated Code ─────────────────────────────────────────────────╮
# │   1 n1 = arr1.size                                                                                              │
# │   2 n2 = arr2.size                                                                                              │
# │   3 p1 = np.mean(arr1)                                                                                          │
# │   4 p2 = np.mean(arr2)                                                                                          │
# │   5 p = (arr1.sum() + arr2.sum()) / (n1 + n2)                                                                   │
# │   6 z = (p1 - p2) / np.sqrt(p * (1 - p) * (1 / n1 + 1 / n2))                                                    │
# │   7 output = z                                                                                                  │
# │   8 print("Z-statistic:", output)                                                                               │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Z-statistic: -0.8716548604640172
# -0.8716548604640172
# ╭──────────────────────────────────────────────── Validation Code ────────────────────────────────────────────────╮
# │   1 n1 = arr1.size                                                                                              │
# │   2 n2 = arr2.size                                                                                              │
# │   3 p1 = np.mean(arr1)                                                                                          │
# │   4 p2 = np.mean(arr2)                                                                                          │
# │   5                                                                                                             │
# │   6 pooled_variance = (p1 * (1 - p1) / n1) + (p2 * (1 - p2) / n2)                                               │
# │   7 z_statistic_expected = (p1 - p2) / np.sqrt(pooled_variance)                                                 │
# │   8                                                                                                             │
# │   9 output = np.allclose(code_out, z_statistic_expected, rtol=1e-5)                                             │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# False
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Validation Failed.                                                                                              │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ ✗ Attempt 2 failed: Validation failed for the output.                                                           │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Attempt 3/3...                                                                                                  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────────────────────── Generated Code ─────────────────────────────────────────────────╮
# │    1 mean1 = np.mean(arr1)                                                                                      │
# │    2 mean2 = np.mean(arr2)                                                                                      │
# │    3 n1 = arr1.size                                                                                             │
# │    4 n2 = arr2.size                                                                                             │
# │    5 sd1 = np.std(arr1)                                                                                         │
# │    6 sd2 = np.std(arr2)                                                                                         │
# │    7                                                                                                            │
# │    8 z = (mean1 - mean2) / np.sqrt((sd1**2 / n1) + (sd2**2 / n2))                                               │
# │    9                                                                                                            │
# │   10 print("Z-statistic:", z)                                                                                   │
# │   11                                                                                                            │
# │   12 output = z                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Z-statistic: -0.8718204746129764
# -0.8718204746129764
# ╭──────────────────────────────────────────────── Validation Code ────────────────────────────────────────────────╮
# │   1 n1 = arr1.size                                                                                              │
# │   2 n2 = arr2.size                                                                                              │
# │   3 p1 = np.mean(arr1)                                                                                          │
# │   4 p2 = np.mean(arr2)                                                                                          │
# │   5 pooled_variance = (p1 * (1 - p1) / n1) + (p2 * (1 - p2) / n2)                                               │
# │   6 z = (p1 - p2) / np.sqrt(pooled_variance)                                                                    │
# │   7                                                                                                             │
# │   8 output = np.isclose(z, code_out, rtol=1e-5)                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# True
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Validation Successful.                                                                                          │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Output                                                                                                          │
# │  -0.8718204746129764                                                                                            │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# -0.8718204746129764

# %%
print(sess.chat("Which group performed better, and is the difference significant?"))
# Out:
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Query: Which group performed better, and is the difference significant?                                         │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Attempt 1/3...                                                                                                  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────────────────────── Generated Code ─────────────────────────────────────────────────╮
# │    1 mean1 = np.mean(arr1)                                                                                      │
# │    2 mean2 = np.mean(arr2)                                                                                      │
# │    3                                                                                                            │
# │    4 print(f"Mean of arr1: {mean1}")                                                                            │
# │    5 print(f"Mean of arr2: {mean2}")                                                                            │
# │    6                                                                                                            │
# │    7 if mean1 > mean2:                                                                                          │
# │    8     print("arr1 performed better.")                                                                        │
# │    9 elif mean2 > mean1:                                                                                        │
# │   10     print("arr2 performed better.")                                                                        │
# │   11 else:                                                                                                      │
# │   12     print("Both groups performed the same.")                                                               │
# │   13                                                                                                            │
# │   14 n1 = arr1.size                                                                                             │
# │   15 n2 = arr2.size                                                                                             │
# │   16 pooled_std = np.sqrt((np.sum((arr1 - mean1)**2) + np.sum((arr2 - mean2)**2)) / (n1 + n2 - 2))              │
# │   17 z = (mean1 - mean2) / (pooled_std * np.sqrt(1/n1 + 1/n2))                                                  │
# │   18                                                                                                            │
# │   19 print(f"Z-statistic: {z}")                                                                                 │
# │   20                                                                                                            │
# │   21 output = z                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Mean of arr1: 0.1
# Mean of arr2: 0.112
# arr2 performed better.
# Z-statistic: -0.8713844553435877
# -0.8713844553435877
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ ✗ Attempt 1 failed: list index out of range                                                                     │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Attempt 2/3...                                                                                                  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────────────────────── Generated Code ─────────────────────────────────────────────────╮
# │    1 mean1 = np.mean(arr1)                                                                                      │
# │    2 mean2 = np.mean(arr2)                                                                                      │
# │    3                                                                                                            │
# │    4 print(f"Conversion rate of group 1: {mean1}")                                                              │
# │    5 print(f"Conversion rate of group 2: {mean2}")                                                              │
# │    6                                                                                                            │
# │    7 if mean1 > mean2:                                                                                          │
# │    8     print("Group 1 performed better.")                                                                     │
# │    9 elif mean2 > mean1:                                                                                        │
# │   10     print("Group 2 performed better.")                                                                     │
# │   11 else:                                                                                                      │
# │   12     print("Both groups performed equally.")                                                                │
# │   13                                                                                                            │
# │   14 n1 = arr1.size                                                                                             │
# │   15 n2 = arr2.size                                                                                             │
# │   16 pooled_std = np.sqrt((np.sum((arr1 - mean1)**2) + np.sum((arr2 - mean2)**2)) / (n1 + n2 - 2))              │
# │   17 z = (mean1 - mean2) / (pooled_std * np.sqrt(1/n1 + 1/n2))                                                  │
# │   18                                                                                                            │
# │   19 print(f"Z-statistic: {z}")                                                                                 │
# │   20                                                                                                            │
# │   21 alpha = 0.05                                                                                               │
# │   22 critical_value = 1.96                                                                                      │
# │   23 if np.abs(z) > critical_value:                                                                             │
# │   24     print("The difference is statistically significant.")                                                  │
# │   25 else:                                                                                                      │
# │   26     print("The difference is not statistically significant.")                                              │
# │   27                                                                                                            │
# │   28 output = z                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Conversion rate of group 1: 0.1
# Conversion rate of group 2: 0.112
# Group 2 performed better.
# Z-statistic: -0.8713844553435877
# The difference is not statistically significant.
# -0.8713844553435877
# ╭──────────────────────────────────────────────── Validation Code ────────────────────────────────────────────────╮
# │    1 mean1 = np.mean(arr1)                                                                                      │
# │    2 mean2 = np.mean(arr2)                                                                                      │
# │    3                                                                                                            │
# │    4 # Calculate the pooled standard error                                                                      │
# │    5 n1 = len(arr1)                                                                                             │
# │    6 n2 = len(arr2)                                                                                             │
# │    7 pooled_se = np.sqrt((mean1 * (1 - mean1) / n1) + (mean2 * (1 - mean2) / n2))                               │
# │    8                                                                                                            │
# │    9 # Calculate the z-statistic                                                                                │
# │   10 z = (mean1 - mean2) / pooled_se                                                                            │
# │   11                                                                                                            │
# │   12 output = z                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# -0.8718204746129764
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Validation Successful.                                                                                          │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Output                                                                                                          │
# │  -0.8713844553435877                                                                                            │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# -0.8713844553435877
